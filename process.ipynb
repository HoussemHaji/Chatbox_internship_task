# %%
import json

# Load the list from the file
with open('all_topics.json', 'r') as f:
    all_topics = json.load(f)

# %%
import numpy as np
from nltk.stem import PorterStemmer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter


# Load GloVe word vectors from a text file 
glove_file_path = "C:\\Users\\houss\\Downloads\\glove.6B\\glove.6B.300d.txt"

def load_glove_embeddings(file_path):
    # Create a dictionary to store word vectors
    embeddings_index = {}
    with open(file_path, encoding="utf8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype="float32")
            embeddings_index[word] = coefs
    return embeddings_index

# Load GloVe embeddings
glove_embeddings = load_glove_embeddings(glove_file_path)

# function to calculate cosine similarity between two topics using GloVe embeddings
def topic_similarity_glove(topic1, topic2, embeddings):
    tokens1 = topic1.split()
    tokens2 = topic2.split()
    embeddings1 = [embeddings.get(token, np.zeros(300)) for token in tokens1]
    embeddings2 = [embeddings.get(token, np.zeros(300)) for token in tokens2]

    if embeddings1 and embeddings2:
        similarity = cosine_similarity(np.mean(embeddings1, axis=0).reshape(1, -1),
                                       np.mean(embeddings2, axis=0).reshape(1, -1))
        return similarity[0, 0]
    else:
        return 0.0

# Group similar topics together using GloVe embeddings
def group_similar_topics_glove(topics, embeddings):
    topic_groups = {}
    topic_frequencies = Counter()

    for topic in topics:
        matched = False
        for group in topic_groups:
            representative_topic = topic_groups[group][0]
            similarity = topic_similarity_glove(topic, representative_topic, embeddings)
            if similarity > 0.6: 
                topic_groups[group].append(topic)
                topic_frequencies[group] += 1
                matched = True
                break
        if not matched:
            topic_groups[topic] = [topic]
            topic_frequencies[topic] += 1

    # Select the most frequent topic in each group as the key
    grouped_topics = {}
    for group, topics in topic_groups.items():
        most_common_topic = max(topics, key=lambda topic: topic_frequencies[topic])
        grouped_topics[most_common_topic] = topics

    return grouped_topics

# Group similar topics using GloVe embeddings
similar_topic_groups = group_similar_topics_glove(all_topics, glove_embeddings)

# Print the grouped topics
for group, topics in similar_topic_groups.items():
    print(f"Group {group}: {topics}")
# Out:
# Group telecommunication: ['telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunications', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication operator', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication', 'telecommunication operator', 'telecommunication package', 'telecom operator']
# Group discount: ['discount', 'discount offer', 'discount', 'discounts', 'discounts', 'discount', 'discount', 'discount', 'discount', 'discount availability', 'discount offer', 'discounts', 'discounts', 'discount', 'discount', 'discounts', 'discount offer', 'discounts', 'discounts', 'discounts', 'discount offer', 'discounts', 'discounts', 'discounts', 'discount offer']
# Group subscription: ['subscription', 'subscriptions', 'subscription', 'subscription', 'subscription cost', 'phone subscription', 'internet subscription', 'subscription', 'subscription', 'subscription', 'mobile subscription', 'mobile phone, customer service, subscription plan, internet package, television package, activation date, billing, customer retention, new offer, contract renewal', 'subscription', 'phone subscription', 'internet subscription', 'internet subscription', 'subscription service', 'product subscription', 'previous subscription', 'service subscription', 'television subscription', 'subscription', 'subscription', 'subscription', 'subscription cost', 'subscription', 'subscription offer', 'subscription', 'subscription', 'subscription', 'subscription', 'subscription', 'subscription', 'subscription', 'subscription', 'subscription verification', 'subscription renewal', 'mobile subscription', 'subscription', 'subscription', 'phone subscription', 'subscription plan', 'subscription', 'subscription plan', 'subscription', 'subscription', 'subscription', 'subscription', 'subscription procedure', 'subscription', 'subscription', 'subscription plan', 'subscriptions', 'subscription plan', 'subscription', 'subscription', 'subscription', 'subscription', 'subscription', 'subscription plan', 'subscription upgrade', 'subscription plan', 'mobile subscription', 'subscription offer', 'subscription card', 'subscription pricing', 'mobile subscription']
# Group contract: ['contract', 'contract termination', 'contract termination', 'contracts', 'contract change', 'contract termination', 'new contract signing', 'contract termination', 'contracts', 'contract duration', 'contract terms', 'contract verification', 'contract', 'contract duration', 'contract expiration', 'contract termination', 'contract renewal', 'contract terms', 'contract terms', 'contract renewal', 'contract terms.', 'contract agreement', 'contract', 'contract', 'contract duration', 'contract transfer', 'new contract', 'contract renewal', 'contract signing', 'contract termination', 'contract renewal', 'phone contract', 'no contract', 'contract renewal', 'contract', 'contract', 'contract duration', 'mobile contract', 'contract validation']
# Group termination: ['termination', 'termination', 'termination', 'termination', 'service termination', 'service termination']
# Group payment: ['payment', 'payment', 'payment method', 'fees', 'payment', 'payment', 'payment responsibility', 'payment', 'payment', 'payment', 'payment', 'payment', 'bill payment', 'payment methods', 'payment', 'payment', 'fees', 'payment methods', 'payment', 'fees', 'payment method', 'payment', 'fees']
# Group unlimited calls: ['unlimited calls', 'unlimited calls', 'unlimited internet', 'phone call', 'unlimited package', 'phone call', 'unlimited calls', 'phone call', 'unlimited calls', 'phone call', 'unlimited calls', 'phone call', 'unlimited call', 'unlimited internet', 'unlimited calls', 'unlimited plan', 'phone call', 'unlimited internet', 'phone call', 'unlimited calls', 'phone subscription, discount offer, unlimited plan, prepayment, contract validation, identification requirements', 'phone call', 'unlimited calls', 'unlimited calls', 'unlimited calls', 'unlimited calls', 'calls', 'unlimited service', 'phone call', 'unlimited service', 'unlimited calls', 'unlimited calls', 'unlimited plan', 'unlimited package', 'unlimited calls', 'unlimited internet', 'phone call', 'unlimited plans', 'phone call', 'unlimited calls', 'phone call', 'unlimited calls', 'unlimited internet']
# Group internet: ['internet', 'internet services', 'internet service', 'internet connection', 'internet subscription, television service, customer service, billing inquiry, telephone service', 'internet', 'phone service', 'internet usage', 'internet package', 'e-mail access', 'internet service', 'internet package', 'social media connectivity', 'internet service', 'home internet', 'internet service', 'internet service', 'internet', 'internet service', 'internet box', 'phone service', 'internet usage', 'internet service', 'internet service', 'internet service', 'french language, telephone conversation, subscription service, internet service, mobile operators, billing issue, customer service.', 'internet service', 'internet', 'internet service', 'internet service', 'internet', 'phone service', 'internet', 'internet service', 'phone usage', 'internet offer', 'internet', 'internet service', 'internet box', 'internet connection', 'internet connection', 'internet package', 'internet', 'internet service', 'mobile phone', 'internet services', 'internet speed', 'internet', 'internet', 'internet service', 'internet package', 'internet usage.', 'internet promotion', 'internet', 'internet package', 'phone services', 'high-speed internet']
# Group traveling: ['traveling', 'travel', 'travel', 'travel']
# Group price change: ['price change', 'cost', 'cost', 'market comparison', 'cost', 'price', 'cost', 'service change', 'service change', 'price plans', 'cost', 'cost', 'price', 'package change', 'cost', 'current plan', 'cost', 'cost', 'change request', 'price', 'price inquiry']
# Group activation date: ['activation date', 'card activation', 'activation', 'activation date']
# Group referral program: ['referral program', 'family referral', 'sponsorship program', 'family referral', 'family referral program']
# Group billing issue: ['billing issue', 'billing', 'technical issue', 'validation issue', 'billing plan', 'issue resolution', 'billing', 'billing', 'billing', 'billing', 'billing', 'billing', 'double billing', 'billing', 'billing', 'billing', 'billing', 'billing', 'technical issue', 'billing issues', 'billing', 'billing', 'billing', 'billing', 'billing', 'billing', 'billing', 'technical issue', 'billing', 'billing issue', 'billing', 'billing issues', 'billing']
# Group flash sale: ['flash sale', 'flash sale']
# Group swiss permit: ['swiss permit', 'switzerland permit', 'swiss permit', 'swiss residency', 'swiss plan', 'permit', 'swiss law', 'swiss card', 'swiss nationality']
# Group e-mail communication: ['e-mail communication', 'email communication', 'client communication', 'communication', 'email correspondence', 'email communication', 'communication', 'email communication', 'communication difficulties', 'communication', 'communication', 'email communication', 'communication problems', 'email communication', 'email communication', 'communication', 'detail email', 'email confirmation', 'email', 'email communication', 'email communication']
# Group nationality: ['nationality', 'nationality', 'nationality', 'nationality', 'nationality']
# Group pricing: ['pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing', 'pricing']
# Group date of birth: ['date of birth', 'birth date', 'return date', 'september date', 'birth date', 'date of birth']
# Group competitive analysis: ['competitive analysis']
# Group telephonic conversation: ['telephonic conversation']
# Group working hours: ['working hours', 'time duration', 'work preparation.', 'work from home', 'work permit.']
# Group callback timing: ['callback timing', 'schedule callback', 'callback arrangement']
# Group reservation: ['reservation', 'reservation', 'reservation', 'reservation', 'reservation']
# Group no obligation: ['no obligation', 'no commitment']
# Group validation mail: ['validation mail', 'validation', 'validation', 'validation', 'validation', 'mail', 'mail']
# Group french citizenship: ['french citizenship', 'french card', 'french language']
# Group rescheduling call: ['rescheduling call', 'call charges.', 'rescheduling calls']
# Group invoice: ['invoice', 'invoice verification', 'invoice', 'invoice']
# Group scanning: ['scanning', 'document scanning']
# Group scheduling: ['scheduling', 'scheduling', 'appointment scheduling', 'appointment scheduling']
# Group discount.: ['discount.']
# Group canada connection: ['canada connection']
# Group administration: ['administration']
# Group driver's license: ["driver's license", 'license']
# Group renovation: ['renovation']
# Group call back: ['call back', 'follow-up call', 'follow-up call', 'call limitations', 'international calling', 'call back', 'call back', 'call back', 'international calls', 'call quality', 'international calls', 'international calls', 'call back', 'call back', 'international calls', 'international calls']
# Group prepaid: ['prepaid', 'prepaid plan', 'prepaid plan', 'prepaid offer', 'prepaid card']
# Group check balance: ['check balance', 'eligibility check']
# Group mobile number portability: ['mobile number portability', 'number identification', 'number', 'number retention.']
# Group sim card (chips): ['sim card (chips)', 'recharge card', 'dual sim', 'sim card issue', 'sim card', 'card receiving', 'sim card delivery', 'sim card replacement', 'card reception', 'card usage instructions']
# Group reschedule: ['reschedule']
# Group delivery: ['delivery', 'delivery', 'hardware delivery', 'equipment delivery', 'delivery', 'modem delivery', 'delivery time', 'delivery']
# Group problem-solving: ['problem-solving', 'problem-solving']
# Group line resiliation: ['line resiliation', 'line re-acquisition', 'line blocking']
# Group number resiliency: ['number resiliency']
# Group transition process: ['transition process']
# Group provider switching.: ['provider switching.', 'provider charges', 'provider change.']
# Group family recommendation: ['family recommendation', 'family plan', 'family members']
# Group documentation: ['documentation', 'documentation', 'documentation']
# Group text messages: ['text messages']
# Group website consultation: ['website consultation', 'website consultation', 'website navigation']
# Group limitations: ['limitations']
# Group location (switzerland): ['location (switzerland)', 'location']
# Group powerful heat: ['powerful heat']
# Group language issue: ['language issue', 'english language']
# Group free number: ['free number', 'contact number', 'number transfer']
# Group decision making.: ['decision making.', 'decision making.', 'decision making']
# Group farewell: ['farewell', 'farewell', 'farewell greeting']
# Group cost evaluation: ['cost evaluation']
# Group photo exchange: ['photo exchange', 'photo coordination']
# Group miscommunication: ['miscommunication']
# Group patience: ['patience']
# Group identity: ['identity']
# Group email.: ['email.']
# Group postal mail.: ['postal mail.', 'postal delay']
# Group confirmation: ['confirmation', 'confirmation', 'client confirmation', 'confirmation']
# Group photo submission: ['photo submission', 'photo id', 'photo submission', 'photo submission']
# Group employment: ['employment']
# Group security: ['security']
# Group migration: ['migration']
# Group questionnaire: ['questionnaire']
# Group contact details: ['contact details', 'contact request', 'contact information']
# Group fiscal reduction: ['fiscal reduction']
# Group future communication.: ['future communication.']
# Group sponsorship: ['sponsorship', 'sponsorship', 'sponsorship']
# Group greetings: ['greetings', 'greetings']
# Group permission: ['permission']
# Group maintenance: ['maintenance']
# Group cancellation: ['cancellation', 'cancellation', 'cancellation', 'cancellation', 'cancellation']
# Group payment.: ['payment.']
# Group client recruitment.: ['client recruitment.']
# Group complaints: ['complaints']
# Group vacation plans: ['vacation plans', 'vacation', 'vacation']
# Group promotions.: ['promotions.']
# Group troubleshooting: ['troubleshooting']
# Group fraud.: ['fraud.']
# Group fiber optic: ['fiber optic', 'fiber technology', 'fiber optic', 'fiber offers', 'fiber connection', 'fiber connection']
# Group surcharge: ['surcharge']
# Group car (presumed): ['car (presumed)', 'cable car']
# Group billing.: ['billing.']
# Group error: ['error']
# Group eligibility: ['eligibility']
# Group notification: ['notification']
# Group household internet.: ['household internet.']
# Group agent involvement: ['agent involvement', 'agent assistance']
# Group business permit: ['business permit']
# Group document requirement: ['document requirement']
# Group moving house: ['moving house']
# Group subsidiary: ['subsidiary']
# Group engagement period: ['engagement period', 'pre-notice period']
# Group two subscriptions: ['two subscriptions']
# Group connectivity: ['connectivity', 'connectivity', 'network connectivity']
# Group negotiation: ['negotiation']
# Group telephony: ['telephony', 'telephony']
# Group sponsorship.: ['sponsorship.']
# Group high stress: ['high stress']
# Group signature: ['signature', 'electronic signature', 'signature']
# Group device purchase.: ['device purchase.']
# Group competition: ['competition']
# Group loyalty benefits: ['loyalty benefits']
# Group commitment-free: ['commitment-free']
# Group sales website: ['sales website', 'sales promotion']
# Group equipment commitment: ['equipment commitment']
# Group recall request: ['recall request']
# Group advantages: ['advantages']
# Group promotion.: ['promotion.']
# Group litigation: ['litigation']
# Group renewal: ['renewal']
# Group tablets: ['tablets', 'tablet']
# Group laptops: ['laptops']
# Group assurance: ['assurance']
# Group service.: ['service.']
# Group identification: ['identification', 'identification']
# Group birthdate: ['birthdate']
# Group monthly recharge: ['monthly recharge']
# Group international messaging: ['international messaging']
# Group registration: ['registration']
# Group confidentiality: ['confidentiality']
# Group public transport: ['public transport']
# Group number retention: ['number retention']
# Group follow-up call.: ['follow-up call.', 'follow-up call.']
# Group stock availability: ['stock availability']
# Group frequency medal: ['frequency medal']

# %%
# Load the list from the file
with open('long_calls.json', 'r') as f:
    long_calls = json.load(f)

# %%
len(long_calls)
# Out:
# 85

# %%
# Load the dictionary from the file
with open('topics_per_call.json', 'r') as f:
    topics_per_call = json.load(f)
    
len(topics_per_call)
# Out:
# 85

# %%
topics_per_call= dict(zip(long_calls, topics_per_call.values()))

topics_per_call
# Out:
# {" customer:[0:00:00.015998]Oui, alors 0:00:00.015998 agent:[0:00:01]Oui, bonjour monsieur, je suis Ciru de l'opérateur téléphonique Allo et on se permet de vous agent:[0:00:06.360000]contacter parce que nous mettons à votre disposition des rabais allant jusqu'à 70 agent:[0:00:10.780000]francs, c'est donc pour vous en faire profiter. customer:[0:00:12.760000]Oui. agent:[0:00:00.170090]Donc, je peux savoir, vous êtes actuellement avec quel opérateur téléphonique déjà 0:00:00.170090 customer:[0:00:19.240000]Alors, aucune idée. customer:[0:00:21.440000]Swisscom, moi, normal. agent:[0:00:23.640000]D'accord. agent:[0:00:00.200001]Et vous êtes engagé avec Swisscom 0:00:00.200001 customer:[0:00:29.360000]J'ai un abonnement aussi. agent:[0:00:00.251001]Oui, donc un abonnement avec un engagement d'un an par exemple 0:00:00.251001 customer:[0:00:37.320000]Deux ans. customer:[0:00:38.320000]Deux ans. agent:[0:00:00.276001]Et vous avez récemment révélé votre contrat 0:00:00.276001 customer:[0:00:40.320000]Non, je vais même finir avec eux parce que c'est pas mal de problèmes. customer:[0:00:41.320000]C'est jamais correct avec eux. customer:[0:00:43.320000]Alors, ça va finir dans deux mois. agent:[0:00:44.320000]Dans deux mois, d'accord. agent:[0:00:00.369015]Actuellement, vous payez combien chez Swisscom 0:00:00.369015 agent:[0:00:46.320000]100 francs. agent:[0:00:00.410053]Et vous bénéficiez de quel avantage 0:00:00.410053 customer:[0:01:03.360000]Tout. customer:[0:00:00.424018]Tout 0:00:00.424018 customer:[0:01:05.360000]J'ai des appels illimités à l'étranger. agent:[0:00:00.462019]Vous avez des appels illimités vers l'étranger 0:00:00.462019 customer:[0:01:07.360000]Oui. customer:[0:01:08.360000]À l'étranger. customer:[0:01:09.360000]Oui. agent:[0:00:00.536016]À l'étranger ou bien vers l'étranger 0:00:00.536016 customer:[0:01:16.360000]Vers l'étranger et à l'étranger aussi. agent:[0:01:23.360000]Ah d'accord. agent:[0:00:00.561021]Et vous avez Internet également 0:00:00.561021 customer:[0:01:28.360000]Oui, illimité à l
#   'contract validation',
#   'email communication',
#   'subscription pricing',
#   'card reception',
#   'postal delay',
#   'mobile subscription',
#   'card usage instructions',
#   'frequency medal',
#   'family referral program',
#   'customer service',
#   'farewell greeting']}

# %%
for k, topics in topics_per_call.items() : 
    for i, topic in enumerate(topics):
        for group , items in similar_topic_groups.items():
            if topic in items :
                topics_per_call[k][i] = group 
                break

# %%
for k, topics in topics_per_call.items():
        topics_per_call[k]=list(set(topics_per_call[k]))

# %%
# to check if the topics changed
for topics in topics_per_call.values():
    if "billing" in topics :
        print("hello")
        break

# %%
# Save the dictionary to a file
with open('final_topics.json', 'w') as f:
    json.dump(topics_per_call, f)

# %%
topics_list = []
for k, topics in topics_per_call.items():
    topics_list.extend(topics)

# %%
topics_list
# Out:
# ['contract',
#  'termination',
#  'payment',
#  'customer service.',
#  'telecommunication',
#  'internet',
#  'traveling',
#  'subscription',
#  'unlimited calls',
#  'price change',
#  'discount',
#  'phone operator',
#  'promotions',
#  'customer service.',
#  'data collection',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'personal information.',
#  'address verification',
#  'contract',
#  'payment',
#  'account access',
#  'customer service.',
#  'offers.',
#  'internet',
#  'subscription',
#  'television service',
#  'new offer',
#  'referral program',
#  'customer service.',
#  'billing issue',
#  'activation date',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'internet',
#  'swiss permit',
#  'contract',
#  'phone operator',
#  'customer service.',
#  'nationality',
#  'billing issue',
#  'flash sale',
#  'telecommunication',
#  'data collection',
#  'subscription',
#  'pricing',
#  'address verification',
#  'e-mail communication',
#  'date of birth',
#  'television service',
#  'contract',
#  'promotions',
#  'phone operator',
#  'customer service.',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'pricing',
#  'competitive analysis',
#  'contract',
#  'phone operator',
#  'customer service.',
#  'callback timing',
#  'billing issue',
#  'data collection',
#  'working hours',
#  'unlimited calls',
#  'telephonic conversation',
#  'discount',
#  'swiss permit',
#  'contract',
#  'new offer',
#  'reservation',
#  'french citizenship',
#  'rescheduling call',
#  'internet',
#  'no obligation',
#  'discount',
#  'unlimited calls',
#  'validation mail',
#  'personal information.',
#  'price change',
#  'swiss permit',
#  'scheduling',
#  'scanning',
#  'reservation',
#  'french citizenship',
#  'billing issue',
#  'unlimited calls',
#  'validation mail',
#  'subscription',
#  'invoice',
#  'personal information.',
#  'address verification',
#  'new offer',
#  'internet',
#  'subscription',
#  'unlimited calls',
#  'pricing',
#  'discount.',
#  'television service',
#  'call back',
#  "driver's license",
#  'reservation',
#  'payment',
#  'billing issue',
#  'administration',
#  'internet',
#  'subscription',
#  'pricing',
#  'canada connection',
#  'renovation',
#  'address verification',
#  'e-mail communication',
#  'television service',
#  'subscription',
#  'swiss permit',
#  'phone operator',
#  'promotions',
#  'customer service.',
#  'prepaid',
#  'telecommunication',
#  'data collection',
#  'check balance',
#  'internet',
#  'no obligation',
#  'unlimited calls',
#  'validation mail',
#  'address verification',
#  'mobile number portability',
#  'price change',
#  'reschedule',
#  'problem-solving',
#  'contract',
#  'termination',
#  'customer service.',
#  'billing issue',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'delivery',
#  'sim card (chips)',
#  'discount',
#  'call back',
#  'payment',
#  'customer service.',
#  'billing issue',
#  'telecommunication',
#  'invoice',
#  'line resiliation',
#  'swiss permit',
#  'number resiliency',
#  'phone operator',
#  'customer service.',
#  'data collection',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'pricing',
#  'scheduling',
#  'family recommendation',
#  'contract',
#  'payment',
#  'new offer',
#  'documentation',
#  'customer service.',
#  'telecommunication',
#  'subscription',
#  'discount',
#  'new offer',
#  'customer service.',
#  'data collection',
#  'internet',
#  'traveling',
#  'subscription',
#  'unlimited calls',
#  'pricing',
#  'price change',
#  'text messages',
#  'sim card (chips)',
#  'television service',
#  'website consultation',
#  'call back',
#  'new offer',
#  'payment',
#  'limitations',
#  'customer service.',
#  'data collection',
#  'working hours',
#  'internet',
#  'subscription',
#  'unlimited calls',
#  'location (switzerland)',
#  'price change',
#  'decision making.',
#  'powerful heat',
#  'language issue',
#  'customer service.',
#  'billing issue',
#  'internet',
#  'subscription',
#  'farewell',
#  'free number',
#  'e-mail communication',
#  'cost evaluation',
#  'new offer',
#  'customer service.',
#  'billing issue',
#  'data collection',
#  'internet',
#  'subscription',
#  'problem-solving',
#  'miscommunication',
#  'customer service.',
#  'photo exchange',
#  'unlimited calls',
#  'patience',
#  'address verification',
#  'e-mail communication',
#  'mobile number portability',
#  'swiss permit',
#  'new offer',
#  'payment',
#  'phone operator',
#  'nationality',
#  'identity',
#  'address verification',
#  'internet',
#  'subscription',
#  'email.',
#  'delivery',
#  'sim card (chips)',
#  'mobile number portability',
#  'price change',
#  'call back',
#  'new offer',
#  'payment',
#  'phone operator',
#  'customer service.',
#  'documentation',
#  'prepaid',
#  'telecommunication',
#  'unlimited calls',
#  'pricing',
#  'location (switzerland)',
#  'postal mail.',
#  'address verification',
#  'e-mail communication',
#  'discount',
#  'scanning',
#  'payment',
#  'account access',
#  'phone operator',
#  'customer service.',
#  'confirmation',
#  'employment',
#  'data collection',
#  'security',
#  'validation mail',
#  'subscription',
#  'photo submission',
#  'personal information.',
#  'address verification',
#  'e-mail communication',
#  'new offer',
#  'migration',
#  'phone operator',
#  'customer service.',
#  'contact details',
#  'subscription',
#  'questionnaire',
#  'price change',
#  'television service',
#  'payment',
#  'phone operator',
#  'customer service.',
#  'internet',
#  'television service',
#  'subscription',
#  'unlimited calls',
#  'fiscal reduction',
#  'discount',
#  'payment',
#  'promotions',
#  'customer service.',
#  'free number',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'validation mail',
#  'pricing',
#  'e-mail communication',
#  'invoice',
#  'personal information.',
#  'price change',
#  'discount',
#  'family recommendation',
#  'contract',
#  'payment',
#  'referral program',
#  'customer service.',
#  'internet',
#  'subscription',
#  'line resiliation',
#  'address verification',
#  'future communication.',
#  'date of birth',
#  'price change',
#  'call back',
#  'scheduling',
#  'phone operator',
#  'customer service.',
#  'sponsorship',
#  'billing issue',
#  'telecommunication',
#  'website consultation',
#  'maintenance',
#  'new offer',
#  'phone operator',
#  'permission',
#  'greetings',
#  'contract',
#  'new offer',
#  'promotions',
#  'customer service.',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'pricing',
#  'discount.',
#  'contract',
#  'phone operator',
#  'customer service.',
#  'billing issue',
#  'sim card (chips)',
#  'discount',
#  'payment.',
#  'telecommunication',
#  'subscription',
#  'cancellation',
#  'television service',
#  'phone operator',
#  'customer service.',
#  'telecommunication',
#  'internet',
#  'television service',
#  'subscription',
#  'unlimited calls',
#  'client recruitment.',
#  'discount',
#  'vacation plans',
#  'customer service.',
#  'telecommunication',
#  'internet',
#  'television service',
#  'subscription',
#  'delivery',
#  'complaints',
#  'discount',
#  'internet',
#  'promotions.',
#  'customer service.',
#  'telecommunication',
#  'internet',
#  'television service',
#  'subscription',
#  'delivery',
#  'e-mail communication',
#  'discount',
#  'new offer',
#  'phone operator',
#  'customer service.',
#  'data collection',
#  'prepaid',
#  'billing issue',
#  'troubleshooting',
#  'subscription',
#  'farewell',
#  'greetings',
#  'fraud.',
#  'termination',
#  'customer service.',
#  'billing issue',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'pricing',
#  'free number',
#  'discount',
#  'contract',
#  'new offer',
#  'phone operator',
#  'customer service.',
#  'billing issue',
#  'internet',
#  'discount',
#  'subscription',
#  'unlimited calls',
#  'fiber optic',
#  'address verification',
#  'television service',
#  'contract',
#  'termination',
#  'phone operator',
#  'customer service.',
#  'internet',
#  'subscription',
#  'pricing',
#  'contract',
#  'customer service.',
#  'rescheduling call',
#  'surcharge',
#  'billing issue',
#  'data collection',
#  'unlimited calls',
#  'subscription',
#  'call back',
#  'car (presumed)',
#  'vacation plans',
#  'new offer',
#  'internet',
#  'subscription',
#  'unlimited calls',
#  'pricing',
#  'e-mail communication',
#  'date of birth',
#  'discount',
#  'call back',
#  'promotions',
#  'customer service.',
#  'phone operator',
#  'data collection',
#  'telecommunication',
#  'subscription',
#  'customer service.',
#  'sim card (chips)',
#  'referral program',
#  'payment',
#  'contract',
#  'contact details',
#  'customer service.',
#  'subscription',
#  'price change',
#  'discount',
#  'contract',
#  'billing.',
#  'customer service.',
#  'data collection',
#  'internet',
#  'subscription',
#  'address verification',
#  'price change',
#  'unlimited calls',
#  'new offer',
#  'promotions',
#  'customer service.',
#  'error',
#  'billing issue',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'decision making.',
#  'address verification',
#  'household internet.',
#  'promotions',
#  'data collection',
#  'telecommunication',
#  'notification',
#  'internet',
#  'subscription',
#  'unlimited calls',
#  'eligibility',
#  'fiber optic',
#  'price change',
#  'document requirement',
#  'business permit',
#  'french citizenship',
#  'language issue',
#  'agent involvement',
#  'internet',
#  'date of birth',
#  'new offer',
#  'payment',
#  'phone operator',
#  'documentation',
#  'nationality',
#  'billing issue',
#  'internet',
#  'moving house',
#  'delivery',
#  'sim card (chips)',
#  'address verification',
#  'call back',
#  'new offer',
#  'payment',
#  'phone operator',
#  'subsidiary',
#  'billing issue',
#  'subscription',
#  'television service',
#  'engagement period',
#  'contract',
#  'termination',
#  'new offer',
#  'phone operator',
#  'two subscriptions',
#  'connectivity',
#  'billing issue',
#  'internet',
#  'address verification',
#  'customer service.',
#  'negotiation',
#  'internet',
#  'subscription',
#  'pricing',
#  'e-mail communication',
#  'television service',
#  'call back',
#  'customer service.',
#  'telecommunication',
#  'internet',
#  'traveling',
#  'subscription',
#  'unlimited calls',
#  'delivery',
#  'discount',
#  'contract',
#  'payment',
#  'promotions',
#  'phone operator',
#  'customer service.',
#  'confirmation',
#  'billing issue',
#  'internet',
#  'subscription',
#  'sponsorship.',
#  'telephony',
#  'e-mail communication',
#  'discount',
#  'website consultation',
#  'new offer',
#  'customer service.',
#  'telecommunication',
#  'personal information.',
#  'e-mail communication',
#  'high stress',
#  'contract',
#  'account access',
#  'phone operator',
#  'customer service.',
#  'confirmation',
#  'working hours',
#  'e-mail communication',
#  'address verification',
#  'sim card (chips)',
#  'contract',
#  'phone operator',
#  'customer service.',
#  'fiber optic',
#  'billing issue',
#  'internet',
#  'signature',
#  'device purchase.',
#  'photo submission',
#  'cancellation',
#  'e-mail communication',
#  'television service',
#  'swiss permit',
#  'competition',
#  'contract',
#  'reservation',
#  'nationality',
#  'sponsorship',
#  'address verification',
#  'flash sale',
#  'internet',
#  'subscription',
#  'validation mail',
#  'cancellation',
#  'telephony',
#  'e-mail communication',
#  'date of birth',
#  'discount',
#  'call back',
#  'contract',
#  'customer service.',
#  'billing issue',
#  'telecommunication',
#  'internet',
#  'unlimited calls',
#  'subscription',
#  'discount',
#  'call back',
#  'scheduling',
#  'customer service.',
#  'loyalty benefits',
#  'data collection',
#  'internet',
#  'commitment-free',
#  'unlimited calls',
#  'subscription',
#  'price change',
#  'rescheduling call',
#  'telecommunication',
#  'check balance',
#  'internet',
#  'sales website',
#  'television service',
#  'subscription',
#  'pricing',
#  'fiber optic',
#  'address verification',
#  'e-mail communication',
#  'discount',
#  'contract',
#  'payment',
#  'termination',
#  'promotions',
#  'customer service.',
#  'provider switching.',
#  'agent involvement',
#  'contact details',
#  'data collection',
#  'billing issue',
#  'subscription',
#  'invoice',
#  'delivery',
#  'e-mail communication',
#  'address verification',
#  'car (presumed)',
#  'equipment commitment',
#  'recall request',
#  'activation date',
#  'unlimited calls',
#  'subscription',
#  'pricing',
#  'delivery',
#  'price change',
#  'vacation plans',
#  'contract',
#  'reservation',
#  'phone operator',
#  'advantages',
#  'connectivity',
#  'billing issue',
#  'telecommunication',
#  'internet',
#  'television service',
#  'subscription',
#  'unlimited calls',
#  'promotion.',
#  'fiber optic',
#  'address verification',
#  'price change',
#  'discount',
#  'family recommendation',
#  'new offer',
#  'payment',
#  'litigation',
#  'phone operator',
#  'tablets',
#  'laptops',
#  'sponsorship',
#  'assurance',
#  'internet',
#  'subscription',
#  'unlimited calls',
#  'service.',
#  'renewal',
#  'price change',
#  'call back',
#  'promotions',
#  'customer service.',
#  'provider switching.',
#  'telecommunication',
#  'internet',
#  'signature',
#  'subscription',
#  'cancellation',
#  'address verification',
#  'contract',
#  'payment',
#  'new offer',
#  'promotions',
#  'customer service.',
#  'phone operator',
#  'tablets',
#  'callback timing',
#  'data collection',
#  'telecommunication',
#  'billing issue',
#  'internet',
#  'television service',
#  'unlimited calls',
#  'cancellation',
#  'e-mail communication',
#  'date of birth',
#  'price change',
#  'new offer',
#  'phone operator',
#  'customer service.',
#  'billing issue',
#  'address verification',
#  'contract',
#  'callback timing',
#  'data collection',
#  'telecommunication',
#  'internet',
#  'unlimited calls',
#  'pricing',
#  'fiber optic',
#  'television service',
#  'call back',
#  'phone operator',
#  'customer service.',
#  'promotions',
#  'connectivity',
#  'data collection',
#  'telecommunication',
#  'working hours',
#  'unlimited calls',
#  'price change',
#  'photo submission',
#  "driver's license",
#  'new offer',
#  'identification',
#  'payment',
#  'phone operator',
#  'customer service.',
#  'confirmation',
#  'nationality',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'unlimited calls',
#  'validation mail',
#  'address verification',
#  'price change',
#  'birthdate',
#  'mobile number portability',
#  'contract',
#  'phone operator',
#  'billing issue',
#  'prepaid',
#  'subscription',
#  'unlimited calls',
#  'monthly recharge',
#  'price change',
#  'call back',
#  'prepaid',
#  'telecommunication',
#  'internet',
#  'subscription',
#  'unlimited calls',
#  'pricing',
#  'decision making.',
#  'international messaging',
#  'contract',
#  'phone operator',
#  'customer service.',
#  'billing issue',
#  'sim card (chips)',
#  'television service',
#  'swiss permit',
#  'registration',
#  'contract',
#  'identification',
#  'new offer',
#  'confidentiality',
#  'billing issue',
#  'working hours',
#  'subscription',
#  'photo submission',
#  'personal information.',
#  'call back',
#  'contract',
#  'payment',
#  'customer service.',
#  'billing issue',
#  'telecommunication',
#  'activation date',
#  'internet',
#  'television service',
#  'unlimited calls',
#  'discount',
#  'contract',
#  'new offer',
#  'follow-up call.',
#  'public transport',
#  'billing issue',
#  'sales website',
#  'number retention',
#  'internet',
#  'subscription',
#  'unlimited calls',
#  'personal information.',
#  'e-mail communication',
#  'price change',
#  'engagement period',
#  'contract',
#  'stock availability',
#  'phone operator',
#  'telecommunication',
#  'traveling',
#  'television service',
#  'unlimited calls',
#  'pricing',
#  'follow-up call.',
#  'discount',
#  'sim card (chips)',
#  'contract',
#  'referral program',
#  'customer service.',
#  'photo exchange',
#  'frequency medal',
#  'subscription',
#  'postal mail.',
#  'farewell',
#  'e-mail communication']

# %%
from collections import Counter

# Calculate the frequency of each topic
frequency = Counter(topics_list)
frequency = sorted(frequency.items(), key=lambda item: item[1], reverse=True)

# %%
frequency
# Out:
# [('subscription', 58),
#  ('customer service.', 56),
#  ('internet', 52),
#  ('telecommunication', 35),
#  ('phone operator', 34),
#  ('contract', 33),
#  ('unlimited calls', 32),
#  ('billing issue', 31),
#  ('new offer', 26),
#  ('discount', 24),
#  ('address verification', 23),
#  ('television service', 22),
#  ('payment', 21),
#  ('price change', 21),
#  ('e-mail communication', 20),
#  ('data collection', 19),
#  ('pricing', 18),
#  ('call back', 15),
#  ('promotions', 13),
#  ('sim card (chips)', 9),
#  ('personal information.', 8),
#  ('swiss permit', 8),
#  ('delivery', 8),
#  ('validation mail', 7),
#  ('termination', 6),
#  ('date of birth', 6),
#  ('fiber optic', 6),
#  ('nationality', 5),
#  ('working hours', 5),
#  ('reservation', 5),
#  ('prepaid', 5),
#  ('cancellation', 5),
#  ('traveling', 4),
#  ('referral program', 4),
#  ('scheduling', 4),
#  ('invoice', 4),
#  ('mobile number portability', 4),
#  ('confirmation', 4),
#  ('photo submission', 4),
#  ('account access', 3),
#  ('activation date', 3),
#  ('callback timing', 3),
#  ('french citizenship', 3),
#  ('rescheduling call', 3),
#  ('family recommendation', 3),
#  ('documentation', 3),
#  ('website consultation', 3),
#  ('decision making.', 3),
#  ('farewell', 3),
#  ('free number', 3),
#  ('contact details', 3),
#  ('sponsorship', 3),
#  ('vacation plans', 3),
#  ('connectivity', 3),
#  ('flash sale', 2),
#  ('no obligation', 2),
#  ('scanning', 2),
#  ('discount.', 2),
#  ("driver's license", 2),
#  ('check balance', 2),
#  ('problem-solving', 2),
#  ('line resiliation', 2),
#  ('location (switzerland)', 2),
#  ('language issue', 2),
#  ('photo exchange', 2),
#  ('postal mail.', 2),
#  ('greetings', 2),
#  ('car (presumed)', 2),
#  ('agent involvement', 2),
#  ('engagement period', 2),
#  ('telephony', 2),
#  ('signature', 2),
#  ('sales website', 2),
#  ('provider switching.', 2),
#  ('tablets', 2),
#  ('identification', 2),
#  ('follow-up call.', 2),
#  ('offers.', 1),
#  ('competitive analysis', 1),
#  ('telephonic conversation', 1),
#  ('administration', 1),
#  ('canada connection', 1),
#  ('renovation', 1),
#  ('reschedule', 1),
#  ('number resiliency', 1),
#  ('text messages', 1),
#  ('limitations', 1),
#  ('powerful heat', 1),
#  ('cost evaluation', 1),
#  ('miscommunication', 1),
#  ('patience', 1),
#  ('identity', 1),
#  ('email.', 1),
#  ('employment', 1),
#  ('security', 1),
#  ('migration', 1),
#  ('questionnaire', 1),
#  ('fiscal reduction', 1),
#  ('future communication.', 1),
#  ('maintenance', 1),
#  ('permission', 1),
#  ('payment.', 1),
#  ('client recruitment.', 1),
#  ('complaints', 1),
#  ('promotions.', 1),
#  ('troubleshooting', 1),
#  ('fraud.', 1),
#  ('surcharge', 1),
#  ('billing.', 1),
#  ('error', 1),
#  ('household internet.', 1),
#  ('notification', 1),
#  ('eligibility', 1),
#  ('document requirement', 1),
#  ('business permit', 1),
#  ('moving house', 1),
#  ('subsidiary', 1),
#  ('two subscriptions', 1),
#  ('negotiation', 1),
#  ('sponsorship.', 1),
#  ('high stress', 1),
#  ('device purchase.', 1),
#  ('competition', 1),
#  ('loyalty benefits', 1),
#  ('commitment-free', 1),
#  ('equipment commitment', 1),
#  ('recall request', 1),
#  ('advantages', 1),
#  ('promotion.', 1),
#  ('litigation', 1),
#  ('laptops', 1),
#  ('assurance', 1),
#  ('service.', 1),
#  ('renewal', 1),
#  ('birthdate', 1),
#  ('monthly recharge', 1),
#  ('international messaging', 1),
#  ('registration', 1),
#  ('confidentiality', 1),
#  ('public transport', 1),
#  ('number retention', 1),
#  ('stock availability', 1),
#  ('frequency medal', 1)]

# %%
# Save the list to a file
with open('topic_freq.json', 'w') as f:
    json.dump(frequency, f)
